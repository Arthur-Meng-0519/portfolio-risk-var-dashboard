# %% [markdown]
# # Prototype Notebook
# Use this notebook to test calculations before moving them into the Streamlit app.

# %%
import pandas as pd
import numpy as np

# Example: simulate portfolio returns
returns = pd.Series(np.random.normal(0.0005, 0.015, 1000))
returns.describe()
